# %% [markdown]
# # 基于CNN模型的物体识别

# %% [markdown]
# ## 1.复习上课内容以及复现课程代码

# %% [markdown]
# 在本部分，你需要复习上课内容和课程代码后，自己复现课程代码。

# %% [markdown]
# ## 2.回答以下理论题目?

# %% [markdown]
# ### 2.1. Suppose your input is a 100 by 100 gray image, and you use a convolutional layer with 50 filters that are each 5x5. How many parameters does this hidden layer have (including the bias parameters)?

# %%
#answer：parameters = (5*5+1)*50 = 1300
(5*5+1)*50

# %% [markdown]
# ### 2.2. What are "local invariant" and "parameter sharing" ?

# %%
"""
answer: 

Local invarient features a paradigm, not just a method to select interesting locations in the image, or to speed up analysis, 
but rather a new image representation, that allows to decribe the objects(parts) without the need of segmentation.

Parameter sharing is sharing of weights by all neurons in a particular feature map.
"""

# %% [markdown]
# ### 2.3. Why we use batch normalization ?

# %%
'''
answer:
Batch Normalization allows us to use much higher learning rates and be less careful about initialization. 
It also acts as a regularizer, in some cases eliminating the need for Dropout.

https://arxiv.org/abs/1502.03167
'''

# %% [markdown]
# ### 2.4. What problem does dropout try to solve ?

# %%
#answer: overfitting

# %% [markdown]
# ## 3. 实践题

# %% [markdown]
# ### 3.1 In the first session of the practical part, you will implement an image classification model using any deep learning libraries that you are familiar with,  which means, except for tensorflow and keras, you can also use pytorch/caffe/... .  The dataset used in this session is the cifar10 which contains 50000 color (RGB) images, each with size 32x32x3.  All 50000 images are classified into ten categories.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import keras

# %% [markdown]
# Load the dataset.

# %%
(x_train,y_train),(x_test,y_test) = tf.keras.datasets.cifar10.load_data()
print(x_train.shape,y_train.shape)
# Out:
# (50000, 32, 32, 3) (50000, 1)

# %%
for i in range(1,11):
    plt.subplot(2,5,i)
    plt.imshow(x_train[i-1])
    plt.text(3,10,str(y_train[i-1]))
    plt.xticks([])
    plt.yticks([])
plt.show()

plt.imshow(x_train[0], interpolation = 'bicubic')
plt.show()

# %%
#nomalize data 
x_train = x_train/255
x_test = x_test/255
y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)
print(x_train.shape,y_train.shape)
# Out:
# (50000, 32, 32, 3) (50000, 10)

# %% [markdown]
# ##### It is your time to build your model. Try your best to build a model with good performance on the test set.

# %%
'''
##不会处理内存问题 -_- 尝试了加lambda层但是报错：iterating over `tf.Tensor` is not allowed in Graph execution. Use Eager execution or decorate this function with @tf.function.

#resize the input images to fit the model
def resize_image(input_img, resized_pix = 224):
    from PIL import Image
    import numpy as np
    
    #the following code has a memory error 
    resized_images = np.array([np.array(Image.fromarray(i).resize((resized_pix,resized_pix), Image.BICUBIC)) for i in input_img])
    
    """
    # the for loop version - cannot fix the memory error
    #create the container 
    resized_images = np.zeros((img_num, resized_pix, resized_pix, img_channel))
    for i in range(0, img_num):
        img = input_img[i]
        img = Image.fromarray(img)
        img = np.array(img.resize(resized_pix, resized_pix), Image.BICUBIC) #resize and change the img back to a numpy array
        resized_images[i,:,:,:] = img    
    """
    return resized_images

'''

# %%
#initialize the model
#My input image should at the size of 224 * 224 * 3, because small-size images cannot fit the model.
from keras.models import Sequential
model = Sequential()

#add layers to the model
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, Reshape
from keras.optimizers import SGD

model.add(Conv2D(32, (3, 3), activation = 'relu', input_shape = (32, 32, 3)))
model.add(Conv2D(32, (3, 3), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Conv2D(64, (3, 3), activation = 'relu'))
model.add(Conv2D(64, (3, 3), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
#model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size = (2, 2)))

#model.add(Conv2D(256, (3, 3), activation='relu'))
#model.add(Conv2D(256, (3, 3), activation='relu'))
#model.add(Conv2D(256, (3, 3), activation='relu'))
#model.add(MaxPooling2D(pool_size = (2, 2)))
#model.add(Conv2D(512, (3, 3), activation='relu'))
#model.add(Conv2D(512, (3, 3), activation='relu'))
#model.add(Conv2D(512, (3, 3), activation='relu'))
#model.add(MaxPooling2D(pool_size = (2, 2)))
#model.add(Conv2D(512, (3, 3), activation='relu'))
#model.add(Conv2D(512, (3, 3), activation='relu'))
#model.add(Conv2D(512, (3, 3), activation='relu'))
#model.add(MaxPooling2D(pool_size = (2, 2)))
#model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(128, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation = 'softmax'))

#optimizer 
sgd = SGD(lr = 0.0001, decay = 1e-6, momentum = 0.9, nesterov = True)
model.compile(loss = 'categorical_crossentropy', optimizer = sgd, metrics = ['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_29"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_116 (Conv2D)          (None, 30, 30, 32)        896
# _________________________________________________________________
# conv2d_117 (Conv2D)          (None, 28, 28, 32)        9248
# _________________________________________________________________
# max_pooling2d_46 (MaxPooling (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_118 (Conv2D)          (None, 12, 12, 64)        18496
# _________________________________________________________________
# conv2d_119 (Conv2D)          (None, 10, 10, 64)        36928
# _________________________________________________________________
# max_pooling2d_47 (MaxPooling (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_120 (Conv2D)          (None, 3, 3, 128)         73856
# _________________________________________________________________
# max_pooling2d_48 (MaxPooling (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 157,226
# Trainable params: 157,226
# Non-trainable params: 0
# _________________________________________________________________

# %%
#apply the model to the data
history = model.fit(x_train, y_train, batch_size=64, epochs=100, verbose=2, validation_data=(x_test, y_test))
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
#  - 13s - loss: 1.8636 - accuracy: 0.3103 - val_loss: 1.7865 - val_accuracy: 0.3555
# Epoch 2/100
#  - 13s - loss: 1.8481 - accuracy: 0.3194 - val_loss: 1.7762 - val_accuracy: 0.3586
# Epoch 3/100
#  - 12s - loss: 1.8325 - accuracy: 0.3264 - val_loss: 1.7559 - val_accuracy: 0.3660
# Epoch 4/100
#  - 12s - loss: 1.8197 - accuracy: 0.3322 - val_loss: 1.7503 - val_accuracy: 0.3728
# Epoch 5/100
#  - 12s - loss: 1.8089 - accuracy: 0.3346 - val_loss: 1.7479 - val_accuracy: 0.3716
# Epoch 6/100
#  - 12s - loss: 1.7987 - accuracy: 0.3414 - val_loss: 1.7277 - val_accuracy: 0.3744
# Epoch 7/100
#  - 12s - loss: 1.7856 - accuracy: 0.3434 - val_loss: 1.7128 - val_accuracy: 0.3878
# Epoch 8/100
#  - 12s - loss: 1.7757 - accuracy: 0.3457 - val_loss: 1.7050 - val_accuracy: 0.3895
# Epoch 9/100
#  - 12s - loss: 1.7664 - accuracy: 0.3526 - val_loss: 1.7107 - val_accuracy: 0.3915
# Epoch 10/100
#  - 12s - loss: 1.7574 - accuracy: 0.3557 - val_loss: 1.6786 - val_accuracy: 0.3972
# Epoch 11/100
#  - 12s - loss: 1.7437 - accuracy: 0.3614 - val_loss: 1.6637 - val_accuracy: 0.3999
# Epoch 12/100
#  - 12s - loss: 1.7364 - accuracy: 0.3655 - val_loss: 1.6642 - val_accuracy: 0.4021
# Epoch 13/100
#  - 12s - loss: 1.7288 - accuracy: 0.3659 - val_loss: 1.6574 - val_accuracy: 0.4036
# Epoch 14/100
#  - 12s - loss: 1.7189 - accuracy: 0.3737 - val_loss: 1.6936 - val_accuracy: 0.3986
# Epoch 15/100
#  - 12s - loss: 1.7095 - accuracy: 0.3759 - val_loss: 1.6351 - val_accuracy: 0.4064
# Epoch 16/100
#  - 12s - loss: 1.7031 - accuracy: 0.3793 - val_loss: 1.6223 - val_accuracy: 0.4182
# Epoch 17/100
#  - 12s - loss: 1.6950 - accuracy: 0.3833 - val_loss: 1.6275 - val_accuracy: 0.4182
# Epoch 18/100
#  - 12s - loss: 1.6895 - accuracy: 0.3839 - val_loss: 1.6306 - val_accuracy: 0.4157
# Epoch 19/100
#  - 12s - loss: 1.6809 - accuracy: 0.3881 - val_loss: 1.6206 - val_accuracy: 0.4217
# Epoch 20/100
#  - 12s - loss: 1.6718 - accuracy: 0.3938 - val_loss: 1.5978 - val_accuracy: 0.4291
# Epoch 21/100
#  - 12s - loss: 1.6649 - accuracy: 0.3946 - val_loss: 1.6051 - val_accuracy: 0.4216
# Epoch 22/100
#  - 12s - loss: 1.6583 - accuracy: 0.3984 - val_loss: 1.5901 - val_accuracy: 0.4318
# Epoch 23/100
#  - 13s - loss: 1.6523 - accuracy: 0.4019 - val_loss: 1.5837 - val_accuracy: 0.4326
# Epoch 24/100
#  - 13s - loss: 1.6482 - accuracy: 0.4016 - val_loss: 1.6177 - val_accuracy: 0.4223
# Epoch 25/100
#  - 13s - loss: 1.6385 - accuracy: 0.4050 - val_loss: 1.5662 - val_accuracy: 0.4416
# Epoch 26/100
#  - 12s - loss: 1.6336 - accuracy: 0.4060 - val_loss: 1.5648 - val_accuracy: 0.4452
# Epoch 27/100
#  - 12s - loss: 1.6258 - accuracy: 0.4105 - val_loss: 1.5635 - val_accuracy: 0.4414
# Epoch 28/100
#  - 12s - loss: 1.6240 - accuracy: 0.4106 - val_loss: 1.5478 - val_accuracy: 0.4461
# Epoch 29/100
#  - 12s - loss: 1.6169 - accuracy: 0.4147 - val_loss: 1.5404 - val_accuracy: 0.4456
# Epoch 30/100
#  - 12s - loss: 1.6116 - accuracy: 0.4158 - val_loss: 1.5440 - val_accuracy: 0.4478
# Epoch 31/100
#  - 12s - loss: 1.6020 - accuracy: 0.4218 - val_loss: 1.5258 - val_accuracy: 0.4543
# Epoch 32/100
#  - 12s - loss: 1.6038 - accuracy: 0.4198 - val_loss: 1.5246 - val_accuracy: 0.4547
# Epoch 33/100
#  - 12s - loss: 1.5940 - accuracy: 0.4220 - val_loss: 1.5273 - val_accuracy: 0.4529
# Epoch 34/100
#  - 13s - loss: 1.5895 - accuracy: 0.4274 - val_loss: 1.5347 - val_accuracy: 0.4554
# Epoch 35/100
#  - 12s - loss: 1.5811 - accuracy: 0.4281 - val_loss: 1.5090 - val_accuracy: 0.4606
# Epoch 36/100
#  - 12s - loss: 1.5810 - accuracy: 0.4278 - val_loss: 1.5294 - val_accuracy: 0.4538
# Epoch 37/100
#  - 12s - loss: 1.5699 - accuracy: 0.4332 - val_loss: 1.4958 - val_accuracy: 0.4670
# Epoch 38/100
#  - 12s - loss: 1.5658 - accuracy: 0.4339 - val_loss: 1.5205 - val_accuracy: 0.4646
# Epoch 39/100
#  - 13s - loss: 1.5636 - accuracy: 0.4366 - val_loss: 1.4843 - val_accuracy: 0.4690
# Epoch 40/100
#  - 12s - loss: 1.5552 - accuracy: 0.4382 - val_loss: 1.4912 - val_accuracy: 0.4704
# Epoch 41/100
#  - 12s - loss: 1.5513 - accuracy: 0.4414 - val_loss: 1.4787 - val_accuracy: 0.4729
# Epoch 42/100
#  - 12s - loss: 1.5476 - accuracy: 0.4407 - val_loss: 1.4770 - val_accuracy: 0.4718
# Epoch 43/100
#  - 13s - loss: 1.5418 - accuracy: 0.4439 - val_loss: 1.4793 - val_accuracy: 0.4697
# Epoch 44/100
#  - 13s - loss: 1.5381 - accuracy: 0.4452 - val_loss: 1.4716 - val_accuracy: 0.4694
# Epoch 45/100
#  - 13s - loss: 1.5331 - accuracy: 0.4468 - val_loss: 1.4604 - val_accuracy: 0.4805
# Epoch 46/100
#  - 12s - loss: 1.5295 - accuracy: 0.4502 - val_loss: 1.4669 - val_accuracy: 0.4779
# Epoch 47/100
#  - 12s - loss: 1.5231 - accuracy: 0.4506 - val_loss: 1.4571 - val_accuracy: 0.4778
# Epoch 48/100
#  - 12s - loss: 1.5212 - accuracy: 0.4495 - val_loss: 1.4547 - val_accuracy: 0.4771
# Epoch 49/100
#  - 13s - loss: 1.5155 - accuracy: 0.4514 - val_loss: 1.4419 - val_accuracy: 0.4832
# Epoch 50/100
#  - 13s - loss: 1.5113 - accuracy: 0.4567 - val_loss: 1.4470 - val_accuracy: 0.4829
# Epoch 51/100
#  - 13s - loss: 1.5059 - accuracy: 0.4594 - val_loss: 1.4465 - val_accuracy: 0.4866
# Epoch 52/100
#  - 12s - loss: 1.4972 - accuracy: 0.4598 - val_loss: 1.4374 - val_accuracy: 0.4887
# Epoch 53/100
#  - 12s - loss: 1.4970 - accuracy: 0.4603 - val_loss: 1.4851 - val_accuracy: 0.4642
# Epoch 54/100
#  - 12s - loss: 1.4950 - accuracy: 0.4612 - val_loss: 1.4235 - val_accuracy: 0.4902
# Epoch 55/100
#  - 12s - loss: 1.4883 - accuracy: 0.4651 - val_loss: 1.4246 - val_accuracy: 0.4891
# Epoch 56/100
#  - 12s - loss: 1.4836 - accuracy: 0.4660 - val_loss: 1.4291 - val_accuracy: 0.4883
# Epoch 57/100
#  - 12s - loss: 1.4793 - accuracy: 0.4691 - val_loss: 1.4232 - val_accuracy: 0.4888
# Epoch 58/100
#  - 12s - loss: 1.4748 - accuracy: 0.4693 - val_loss: 1.4332 - val_accuracy: 0.4916
# Epoch 59/100
#  - 12s - loss: 1.4757 - accuracy: 0.4696 - val_loss: 1.4154 - val_accuracy: 0.4937
# Epoch 60/100
#  - 13s - loss: 1.4669 - accuracy: 0.4743 - val_loss: 1.4051 - val_accuracy: 0.4984
# Epoch 61/100
#  - 12s - loss: 1.4660 - accuracy: 0.4737 - val_loss: 1.4199 - val_accuracy: 0.4960
# Epoch 62/100
#  - 13s - loss: 1.4607 - accuracy: 0.4717 - val_loss: 1.3992 - val_accuracy: 0.5000
# Epoch 63/100
#  - 13s - loss: 1.4558 - accuracy: 0.4737 - val_loss: 1.4203 - val_accuracy: 0.4944
# Epoch 64/100
#  - 13s - loss: 1.4544 - accuracy: 0.4764 - val_loss: 1.3921 - val_accuracy: 0.5026
# Epoch 65/100
#  - 14s - loss: 1.4467 - accuracy: 0.4808 - val_loss: 1.4076 - val_accuracy: 0.4971
# Epoch 66/100
#  - 13s - loss: 1.4462 - accuracy: 0.4803 - val_loss: 1.3925 - val_accuracy: 0.5016
# Epoch 67/100
#  - 13s - loss: 1.4396 - accuracy: 0.4822 - val_loss: 1.3919 - val_accuracy: 0.5001
# Epoch 68/100
#  - 13s - loss: 1.4346 - accuracy: 0.4830 - val_loss: 1.3831 - val_accuracy: 0.5063
# Epoch 69/100
#  - 12s - loss: 1.4298 - accuracy: 0.4845 - val_loss: 1.3826 - val_accuracy: 0.5067
# Epoch 70/100
#  - 13s - loss: 1.4307 - accuracy: 0.4850 - val_loss: 1.3834 - val_accuracy: 0.5077
# Epoch 71/100
#  - 13s - loss: 1.4244 - accuracy: 0.4861 - val_loss: 1.3773 - val_accuracy: 0.5078
# Epoch 72/100
#  - 13s - loss: 1.4210 - accuracy: 0.4888 - val_loss: 1.3753 - val_accuracy: 0.5089
# Epoch 73/100
#  - 13s - loss: 1.4199 - accuracy: 0.4907 - val_loss: 1.3773 - val_accuracy: 0.5077
# Epoch 74/100
#  - 13s - loss: 1.4139 - accuracy: 0.4929 - val_loss: 1.3622 - val_accuracy: 0.5124
# Epoch 75/100
#  - 14s - loss: 1.4115 - accuracy: 0.4935 - val_loss: 1.3548 - val_accuracy: 0.5166
# Epoch 76/100
#  - 14s - loss: 1.4077 - accuracy: 0.4931 - val_loss: 1.3554 - val_accuracy: 0.5157
# Epoch 77/100
#  - 13s - loss: 1.4045 - accuracy: 0.4965 - val_loss: 1.3640 - val_accuracy: 0.5159
# Epoch 78/100
#  - 13s - loss: 1.3986 - accuracy: 0.4957 - val_loss: 1.3431 - val_accuracy: 0.5214
# Epoch 79/100
#  - 13s - loss: 1.3962 - accuracy: 0.4981 - val_loss: 1.3448 - val_accuracy: 0.5198
# Epoch 80/100
#  - 13s - loss: 1.3937 - accuracy: 0.5037 - val_loss: 1.3397 - val_accuracy: 0.5183
# Epoch 81/100
#  - 13s - loss: 1.3870 - accuracy: 0.5016 - val_loss: 1.3403 - val_accuracy: 0.5215
# Epoch 82/100
#  - 13s - loss: 1.3841 - accuracy: 0.5022 - val_loss: 1.3343 - val_accuracy: 0.5238
# Epoch 83/100
#  - 13s - loss: 1.3787 - accuracy: 0.5061 - val_loss: 1.3513 - val_accuracy: 0.5200
# Epoch 84/100
#  - 13s - loss: 1.3757 - accuracy: 0.5073 - val_loss: 1.3610 - val_accuracy: 0.5143
# Epoch 85/100
#  - 13s - loss: 1.3759 - accuracy: 0.5071 - val_loss: 1.3246 - val_accuracy: 0.5249
# Epoch 86/100
#  - 13s - loss: 1.3678 - accuracy: 0.5103 - val_loss: 1.3294 - val_accuracy: 0.5272
# Epoch 87/100
#  - 13s - loss: 1.3700 - accuracy: 0.5101 - val_loss: 1.3214 - val_accuracy: 0.5287
# Epoch 88/100
#  - 13s - loss: 1.3638 - accuracy: 0.5119 - val_loss: 1.3273 - val_accuracy: 0.5260
# Epoch 89/100
#  - 13s - loss: 1.3611 - accuracy: 0.5147 - val_loss: 1.3325 - val_accuracy: 0.5236
# Epoch 90/100
#  - 13s - loss: 1.3553 - accuracy: 0.5148 - val_loss: 1.3201 - val_accuracy: 0.5300
# Epoch 91/100
#  - 13s - loss: 1.3519 - accuracy: 0.5182 - val_loss: 1.3148 - val_accuracy: 0.5331
# Epoch 92/100
#  - 13s - loss: 1.3492 - accuracy: 0.5193 - val_loss: 1.3129 - val_accuracy: 0.5284
# Epoch 93/100
#  - 13s - loss: 1.3482 - accuracy: 0.5172 - val_loss: 1.3168 - val_accuracy: 0.5298
# Epoch 94/100
#  - 13s - loss: 1.3414 - accuracy: 0.5203 - val_loss: 1.3021 - val_accuracy: 0.5378
# Epoch 95/100
#  - 13s - loss: 1.3373 - accuracy: 0.5226 - val_loss: 1.3166 - val_accuracy: 0.5333
# Epoch 96/100
#  - 13s - loss: 1.3344 - accuracy: 0.5254 - val_loss: 1.2912 - val_accuracy: 0.5392
# Epoch 97/100
#  - 13s - loss: 1.3293 - accuracy: 0.5254 - val_loss: 1.2918 - val_accuracy: 0.5384
# Epoch 98/100
#  - 13s - loss: 1.3264 - accuracy: 0.5284 - val_loss: 1.2902 - val_accuracy: 0.5430
# Epoch 99/100
#  - 13s - loss: 1.3241 - accuracy: 0.5267 - val_loss: 1.2913 - val_accuracy: 0.5377
# Epoch 100/100
#  - 13s - loss: 1.3193 - accuracy: 0.5327 - val_loss: 1.2802 - val_accuracy: 0.5414

# %%
score = model.evaluate(x_test, y_test, batch_size=128, verbose=1)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 10000/10000 [==============================] - 1s 97us/step
# Test loss: 1.2801698451995849
# Test accuracy: 0.5414000153541565

# %% [markdown]
# ###  Congratulations! You hanve finished the assignment 3.

# %%
#cite: 
#cifar10 example in keras-
# https://blog.csdn.net/tsyccnh/article/details/78838005
# https://machinelearningmastery.com/how-to-develop-a-cnn-from-scratch-for-cifar-10-photo-classification/
#keras intro doc- https://keras.io/zh/
#resize images in keras- https://www.cnblogs.com/wuliytTaotao/p/11191702.html
